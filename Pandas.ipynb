# %%
import pandas as pd

# %%
obje=pd.Series([1,3,"a","d"])
obje
# Out:
# 0    1
# 1    3
# 2    a
# 3    d
# dtype: object

# %%
obje[1]
# Out:
# 3

# %%
puan={"ali":90,"efe":88,"can":76}
nt=pd.Series(puan)

# %%
nt[nt<80]=88
nt
# Out:
# ali    90
# efe    88
# can    88
# dtype: int64

# %%
nt/10
# Out:
# ali    9.0
# efe    8.8
# can    8.8
# dtype: float64

# %%
nt.isnull()
# Out:
# ali    False
# efe    False
# can    False
# dtype: bool

# %%
b=pd.read_excel("mac.xlsx")

# %%
b.head()
# Out:
#    year team  played  won  drawn  lost  points
# 0  1998   fb      12    8      2     2      33
# 1  1994   gs      14   10      1     3      33
# 2  1994   fb      16   12      2     2      33
# 3  1993   fb      17    9      2     6      33
# 4  1998   gs      19   17      1     1      33

# %%
b.dtypes   # değişken tiplerini gösterir
# Out:
# year       int64
# team      object
# played     int64
# won        int64
# drawn      int64
# lost       int64
# points     int64
# dtype: object

# %%
b.played.value_counts()
# Out:
# 16    2
# 12    1
# 14    1
# 17    1
# 19    1
# 20    1
# 24    1
# 3     1
# Name: played, dtype: int64

# %%
pd.crosstab(b.year,b.team)
# Out:
# team  fb  gs
# year
# 1967   1   0
# 1984   0   1
# 1990   0   1
# 1993   2   0
# 1994   1   1
# 1998   1   1

# %%
# %matplotlib inline

# %%
b.year.plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
b.played.plot(kind="bar")
# Out:
# <Axes: >

# %%
veri={"isim":["ali","can","buse","alp","nur"],
      "puan":[90,80,70,87,65],
      "spor":["futbol","kayak","yüzme","tenis","karate"],
      "cinsiyet":["E","E","K","E","K"]}
veri
# Out:
# {'isim': ['ali', 'can', 'buse', 'alp', 'nur'],
#  'puan': [90, 80, 70, 87, 65],
#  'spor': ['futbol', 'kayak', 'yüzme', 'tenis', 'karate'],
#  'cinsiyet': ['E', 'E', 'K', 'E', 'K']}

# %%
pd.DataFrame(veri)
# Out:
#    isim  puan    spor cinsiyet
# 0   ali    90  futbol        E
# 1   can    80   kayak        E
# 2  buse    70   yüzme        K
# 3   alp    87   tenis        E
# 4   nur    65  karate        K

# %%
d=pd.DataFrame(veri,columns=["isim","spor","cinsiyet","puan","yas"])

# %%
sutun=["isim","cinsiyet"]
d[sutun]
# Out:
#    isim cinsiyet
# 0   ali        E
# 1   can        E
# 2  buse        K
# 3   alp        E
# 4   nur        K

# %%
#d["yas"]=9
d["yas"]=[9,5,4,3,6]
d
# Out:
#    isim    spor cinsiyet  puan  yas
# 0   ali  futbol        E    90    9
# 1   can   kayak        E    80    5
# 2  buse   yüzme        K    70    4
# 3   alp   tenis        E    87    3
# 4   nur  karate        K    65    6

# %%
# satır ve sutunlarıı isimlendirdik
d.index.name="isim"
d.columns.name="ders"
d
# Out:
# ders  isim    spor cinsiyet  puan  yas
# isim
# 0      ali  futbol        E    90    9
# 1      can   kayak        E    80    5
# 2     buse   yüzme        K    70    4
# 3      alp   tenis        E    87    3
# 4      nur  karate        K    65    6

# %%
# değiştirilemez
indeks=d.index
#indeks[2]="can"
# Out:
# '1.5.3'
